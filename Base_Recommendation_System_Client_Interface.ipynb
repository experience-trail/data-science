# %% [markdown]
# # Storing Google Places API data using GraphQL
#
# This notebook documents the process to store data collected using **Google Places API**.

# %% [markdown]
# ### GQL client Interface
#
# [GQL](https://github.com/graphql-python/gql), GraphQL client for Python is being used here to interface with GraphQL backend. **GraphQL** is used to store our JSON data into **MongoDB** for caching.
#
# We intall GQL and create the client as shown below.

# %%
pip install gql
# Out:
# Collecting gql
#   Downloading https://files.pythonhosted.org/packages/aa/9c/2933b7791210e00f5c26a6243198cc03af9132c29cf85e4c22cb007f171e/gql-0.1.0.tar.gz
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from gql) (1.12.0)
# Collecting graphql-core>=0.5.0 (from gql)
#   Downloading https://files.pythonhosted.org/packages/6a/11/bc4a7eb440124271289d93e4d208bd07d94196038fabbe2a52435a07d3d3/graphql_core-2.2.1-py2.py3-none-any.whl (250kB)
#      |████████████████████████████████| 256kB 4.7MB/s
# Requirement already satisfied: promise>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from gql) (2.2.1)
# Collecting rx<3,>=1.6 (from graphql-core>=0.5.0->gql)
#   Downloading https://files.pythonhosted.org/packages/33/0f/5ef4ac78e2a538cc1b054eb86285fe0bf7a5dbaeaac2c584757c300515e2/Rx-1.6.1-py2.py3-none-any.whl (179kB)
#      |████████████████████████████████| 184kB 43.9MB/s
# Building wheels for collected packages: gql
#   Building wheel for gql (setup.py) ... done
#   Created wheel for gql: filename=gql-0.1.0-cp36-none-any.whl size=5540 sha256=8c4717bd3bb7804c3f6bdab7c87e1d1634e522462cdcb39c4ef7d8607fc244b4
#   Stored in directory: /root/.cache/pip/wheels/a7/8d/65/a3247f500d675d80a01e4d2f0ee44fe99f1faef575bc2a1664
# Successfully built gql
# Installing collected packages: rx, graphql-core, gql
# Successfully installed gql-0.1.0 graphql-core-2.2.1 rx-1.6.1

# %%
from gql import Client, gql
from gql.transport.requests import RequestsHTTPTransport
import json

expected_retries = 3
# URL information to be updated.
url='' 


client = Client(retries=expected_retries,
                transport=RequestsHTTPTransport(url=url))

# %% [markdown]
# ### Data Insertion
# The below code is to store static  place id and related details.
#
# Note: Here we are not working with the complete Google Places API output.

# %%
# Hard coded value
# Checking how our API works
createBaseRSPlace = gql('''
mutation createBaseRSPlace {
  create_basers_place(place_data: {place_id: "ChIJN1t_tDeuEmsRUsoyG83frY4", google_place_details: "{\\"place_id\\":\\"ChIJN1t_tDeuEmsRUsoyG83frY4\\",\\"rating\\" : 4.6, \\"name\\" : \\"Google\\"}", timestamp: "2019-06-02T13:44:31+05:30"}) {
    place_id
    ok
    message
  }
}
''')

client.execute(createBaseRSPlace)
# Out:
# {'create_basers_place': {'message': 'Success',
#   'ok': True,
#   'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'}}

# %% [markdown]
# The below code shows how to store place id and related info dynamically into our database

# %%
# Dynamic variable
createBaseRSPlace = gql('''
mutation createBaseRSPlace($place_id: String!, 
                           $google_place_details: JSONString!,
                           $timestamp: CustomGrapheneDateTime!) {
  create_basers_place(place_data: {place_id: $place_id, 
                                   google_place_details: $google_place_details, 
                                   timestamp: $timestamp}) {
    place_id
    ok
    message
  }
}
''')

params = '''{
    "place_id": "ChIJN1t_tDeuEmsRUsoyG83frY4",
    "google_place_details": "{\\"place_id\\":\\"ChIJN1t_tDeuEmsRUsoyG83frY4\\",\\"rating\\" : 4.6, \\"name\\" : \\"Google\\"}",
    "timestamp": "2019-06-02T13:44:31+05:30"
}'''

client.execute(createBaseRSPlace, variable_values=params)
# Out:
# {'create_basers_place': {'message': 'Success',
#   'ok': True,
#   'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'}}

# %% [markdown]
# ### Data Retrival: Checking Place details
# The code below checks how static place details are stored in our database.

# %%
# Hard coded value
# This again is hard coded where the variables aren't changing 
queryBaseRSPlaceDetails = gql('''
query queryBaseRSPlaceDetails {
  basers_place_details(place_id: "ChIJN1t_tDeuEmsRUsoyG83frY4") {
    place_id
    google_place_details
  }
}
''')

client.execute(queryBaseRSPlaceDetails)
# Out:
# {'basers_place_details': {'google_place_details': '{"place_id": "ChIJN1t_tDeuEmsRUsoyG83frY4", "rating": 4.6, "name": "Google"}',
#   'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'}}

# %% [markdown]
# Dynamically retrieving the information from our database.

# %%
# Dynamic variable
queryBaseRSPlaceDetails = gql('''
query queryBaseRSPlaceDetails($place_id: String!) {
  basers_place_details(place_id: $place_id) {
    place_id
    google_place_details
  }
}
''')

params = '''{
    "place_id": "ChIJbf8C1yFxdDkR3n12P4DkKt0"
}'''

client.execute(queryBaseRSPlaceDetails, variable_values=params)
# Out:
# {'basers_place_details': {'google_place_details': '{"address_components": [{"long_name": "Dharmapuri", "short_name": "Dharmapuri", "types": ["neighborhood", "political"]}, {"long_name": "Forest Colony", "short_name": "Forest Colony", "types": ["sublocality_level_2", "sublocality", "political"]}, {"long_name": "Tajganj", "short_name": "Tajganj", "types": ["sublocality_level_1", "sublocality", "political"]}, {"long_name": "Agra", "short_name": "Agra", "types": ["locality", "political"]}, {"long_name": "Agra", "short_name": "Agra", "types": ["administrative_area_level_2", "political"]}, {"long_name": "Uttar Pradesh", "short_name": "UP", "types": ["administrative_area_level_1", "political"]}, {"long_name": "India", "short_name": "IN", "types": ["country", "political"]}, {"long_name": "282001", "short_name": "282001", "types": ["postal_code"]}], "adr_address": "<span class=\'extended-address\'>Dharmapuri, Forest Colony, Tajganj</span>, <span class=\'locality\'>Agra</span>, <span class=\'region\'>Uttar Pradesh</span> <span class=\'postal-code\'>282001</span>, <span class=\'country-name\'>India</span>", "formatted_address": "Dharmapuri, Forest Colony, Tajganj, Agra, Uttar Pradesh 282001, India", "formatted_phone_number": "0562 222 7261", "geometry": {"location": {"lat": 27.1751448, "lng": 78.0421422}, "viewport": {"northeast": {"lat": 27.1772325, "lng": 78.04546859999999}, "southwest": {"lat": 27.1688817, "lng": 78.03880380000001}}}, "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png", "id": "dcc9586b99ab0f0471fccecbe2dbb40fdc1fc2b5", "international_phone_number": "+91 562 222 7261", "name": "Taj Mahal", "photos": [{"height": 669, "html_attributions": ["<a href=\'https://maps.google.com/maps/contrib/115037799946808526568/photos\'>agus zainuddin</a>"], "photo_reference": "CmRaAAAA01qa_QnMjAnOdKthBgT-t6JdGjNYxMymXfC9-51K2avOTPYlwzY1aJxHT02hS_mj1XAdQOZmJyruz0n-tu534KsutgkfQ6X10AqOWTzuhPK6OllcsJ3El_sYynXeS_UYEhCwIqsX4Mdd9kAOLZ1tKE09GhR3H7H_zt0HdTY4xWv3ubqDyOhn3w", "width": 1191}, {"height": 2160, "html_attributions": ["<a href=\'https://maps.google.com/maps/contrib
place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA'},
#   {'place_id': 'ChIJuU2C7F5E04kRiKK9VmHF0kY'},
#   {'place_id': 'ChIJrwO1fgcmMxURNKNBOlKTnJw'},
#   {'place_id': 'ChIJaXQRs6lZwokRY6EFpJnhNNE'},
#   {'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'},
#   {'place_id': 'ChIJw____96GhYARCVVwg5cT7c0'},
#   {'place_id': 'ChIJ-aH5AxFwrzsRDdokoeK6f8M'},
#   {'place_id': 'ChIJ42MF8e0VrjsRPoV7_ygSOhQ'},
#   {'place_id': 'ChIJ2dGMjMMEdkgRqVqkuXQkj7c'},
#   {'place_id': 'ChIJj2HZewpZ0IkRCRdRnhG9LNQ'},
#   {'place_id': 'ChIJGymPrIdFWBQRJCSloj8vDIE'},
#   {'place_id': 'ChIJzyx_aNch8TUR3yIFlZslQNA'},
#   {'place_id': 'ChIJzYhOxKaR1RIRA_xU1bGp7DI'},
#   {'place_id': 'ChIJuzIBtptoUjoRCrZi347PSQU'}]}

# %% [markdown]
# ### Data Removal: Deleting entries from our database
# The below code is to delete a particular entry from our database

# %%
# Hard coded value
deleteBaseRSPlace = gql('''
mutation deleteBaseRSPlace {
  delete_basers_place(place_data: {place_id: "ChIJN1t_tDeuEmsRUsoyG83frY4"}) {
    place_id
    ok
    message
  }
}
''')
client.execute(deleteBaseRSPlace)
# Out:
# {'delete_basers_place': {'message': 'Success',
#   'ok': True,
#   'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'}}

# %% [markdown]
# Once the place is deleted, running the code again will result in the warning that "Delete from Mongo DB failed" because the same entry can't be deleted twice.
#
# This code below shows dynamically passing variables for deleting from our database.

# %%
# Dynamic variable
deleteBaseRSPlace = gql('''
mutation deleteBaseRSPlace($place_id: String!) {
  delete_basers_place(place_data: {place_id: $place_id}) {
    place_id
    ok
    message
  }
}
''')

params = '''{
    "place_id": "ChIJw____96GhYARCVVwg5cT7c0"
}'''

client.execute(deleteBaseRSPlace, variable_values=params)
# Out:
# {'delete_basers_place': {'message': 'Delete from MongoDB failed',
#   'ok': False,
#   'place_id': 'ChIJw____96GhYARCVVwg5cT7c0'}}

# %% [markdown]
# # Working with Real Data
#
# The below dictionary is the output for a particular Place ID that we retrived from Google Place API. Google Place API to search for any specific places e.g. **Statue or Liberty; Golden Gate Bridge...** Once you run that code, the output gives you place ID.
#
# We used that **Place ID** to query the below JSON result.

# %%
place_details = {'html_attributions': [],
 'result': {'address_components': [{'long_name': 'New York',
    'short_name': 'New York',
    'types': ['locality', 'political']},
   {'long_name': 'Manhattan',
    'short_name': 'Manhattan',
    'types': ['sublocality_level_1', 'sublocality', 'political']},
   {'long_name': 'New York County',
    'short_name': 'New York County',
    'types': ['administrative_area_level_2', 'political']},
   {'long_name': 'New York',
    'short_name': 'NY',
    'types': ['administrative_area_level_1', 'political']},
   {'long_name': 'United States',
    'short_name': 'US',
    'types': ['country', 'political']},
   {'long_name': '10004', 'short_name': '10004', 'types': ['postal_code']}],
  'adr_address': '<span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10004</span>, <span class="country-name">USA</span>',
  'formatted_address': 'New York, NY 10004, USA',
  'formatted_phone_number': '(212) 363-3200',
  'geometry': {'location': {'lat': 40.6892494, 'lng': -74.04450039999999},
   'viewport': {'northeast': {'lat': 40.71814749999999,
     'lng': -73.99872490000001},
    'southwest': {'lat': 40.6796167, 'lng': -74.05975889999998}}},
  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
  'id': '5a0d7e67078e35af0c456a277df9ffba7c1e4da6',
  'international_phone_number': '+1 212-363-3200',
  'name': 'Statue of Liberty National Monument',
  'opening_hours': {'open_now': False,
   'periods': [{'close': {'day': 0, 'time': '1600'},
     'open': {'day': 0, 'time': '0830'}},
    {'close': {'day': 1, 'time': '1600'}, 'open': {'day': 1, 'time': '0830'}},
    {'close': {'day': 2, 'time': '1600'}, 'open': {'day': 2, 'time': '0830'}},
    {'close': {'day': 3, 'time': '1600'}, 'open': {'day': 3, 'time': '0830'}},
    {'close': {'day': 4, 'time': '1600'}, 'open': {'day': 4, 'time': '0830'}},
    {'close': {'day': 5, 'time': '1600'}, 'open': {'day': 5, 'time': '0830'}},
    {'close': {'day': 6, 'time': '1600'}, 'open': {'day': 6, 'time': '0830'}}],
   'weekday_text': ['Monday: 8:30 AM – 4:00 PM',
    'Tuesday: 8:30 AM – 4:00 PM',
    'Wednesday: 8:30 AM – 4:00 PM',
    'Thursday: 8:30 AM – 4:00 PM',
    'Friday: 8:30 AM – 4:00 PM',
    'Saturday: 8:30 AM – 4:00 PM',
    'Sunday: 8:30 AM – 4:00 PM']},
  'photos': [{'height': 5312,
    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118296288152495182017/photos">miki nogal</a>'],
    'photo_reference': 'CmRaAAAA-r2MC6tSDKxHfYIuasA7QRLvrrR9pcBv46S7VKT9YC0mRy1_POzj2p_gAeMMV-udsdDh7sgAkri3ESf3LOR97eE_H6tpTxjFj5yF4hxk6zfs_G9yFy8pb5H4FsPllu2IEhCJz7N6JG0DuiY_QOVI5XPRGhRXSDhu2s5f9KOeb8BrN8ij2m6htg',
    'width': 2988},
   {'height': 4608,
    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106265366409122628933/photos">Isabel Castañeda</a>'],
    'photo_reference': 'CmRaAAAAMV7D_TqTKZfJ1hjXx9D89ifdPjPn7MmxunUn1Id1N8r3JoDaEeZt3CVB1-_H0oHZG5tWlNfNCheAL6M-pdxbajW6HJ4TVvnmmKjZAbYzza5KRcZn5PSWU_p8kELxtCvMEhBDIpRneg3eeiTT3JWSHiLcGhQAfqehQBwiZalBw3l5-D8wiNsM-w',
    'width': 3456},
   {'height': 2322,
    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112798933856821576176/photos">Jiasu BECERRA Y PACHECO</a>'],
    'photo_reference': 'CmRaAAAAwH3lqtHdmCm2Ki-fdoTlcLAgKqmr_NG-yWjWn4X5LZo2ZXnzwOM9oQ7nuAjgPQdvGBZ4ONZhsKQthrSuvr_r4EsB6QPeo3Zg6KqXAFyk69k_bNmbLeq3X2rSF0rWUBDhEhDly3R-IAt_KEVGF_NCwd04GhSpM62lQl_OEBv5EVtLSrRXfZOB0A',
    'width': 4128},
   {'height': 5184,
    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/
'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111177214989513874707/photos">Beny Jackson</a>'],
    'photo_reference': 'CmRaAAAAVOOSUO12_HLCSQdrWMg_wvSY9GtsMxRk-Gv_lo0aAdF9CjVuO1sBTOQ9Pnzvzw3NuxYId6tcvtK54JFMOjoywMX19t2Ja9iaYPJxxzA3waDEvgy5nVsBLTdTC4Xt05mVEhALcIs0LPAfz_2I7g4WjNYYGhRtNlJDC_TUHuPA2gnRupc23uJ_nA',
    'width': 3456}],
  'place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA',
  'plus_code': {'compound_code': 'MXQ4+M5 New York, United States',
   'global_code': '87G7MXQ4+M5'},
  'rating': 4.6,
  'reference': 'ChIJPTacEpBQwokRKwIlDXelxkA',
  'scope': 'GOOGLE',
  'types': ['park', 'point_of_interest', 'establishment'],
  'url': 'https://maps.google.com/?cid=4667599994556318251',
  'user_ratings_total': 54426,
  'utc_offset': -240,
  'vicinity': 'New York',
  'website': 'https://www.nps.gov/stli/index.htm'},
 'status': 'OK'}
# Out:
# {"html_attributions": [], "result": {"address_components": [{"long_name": "New York", "short_name": "New York", "types": ["locality", "political"]}, {"long_name": "Manhattan", "short_name": "Manhattan", "types": ["sublocality_level_1", "sublocality", "political"]}, {"long_name": "New York County", "short_name": "New York County", "types": ["administrative_area_level_2", "political"]}, {"long_name": "New York", "short_name": "NY", "types": ["administrative_area_level_1", "political"]}, {"long_name": "United States", "short_name": "US", "types": ["country", "political"]}, {"long_name": "10004", "short_name": "10004", "types": ["postal_code"]}], "adr_address": "<span class=\"locality\">New York</span>, <span class=\"region\">NY</span> <span class=\"postal-code\">10004</span>, <span class=\"country-name\">USA</span>", "formatted_address": "New York, NY 10004, USA", "formatted_phone_number": "(212) 363-3200", "geometry": {"location": {"lat": 40.6892494, "lng": -74.04450039999999}, "viewport": {"northeast": {"lat": 40.71814749999999, "lng": -73.99872490000001}, "southwest": {"lat": 40.6796167, "lng": -74.05975889999998}}}, "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png", "id": "5a0d7e67078e35af0c456a277df9ffba7c1e4da6", "international_phone_number": "+1 212-363-3200", "name": "Statue of Liberty National Monument", "opening_hours": {"open_now": false, "periods": [{"close": {"day": 0, "time": "1600"}, "open": {"day": 0, "time": "0830"}}, {"close": {"day": 1, "time": "1600"}, "open": {"day": 1, "time": "0830"}}, {"close": {"day": 2, "time": "1600"}, "open": {"day": 2, "time": "0830"}}, {"close": {"day": 3, "time": "1600"}, "open": {"day": 3, "time": "0830"}}, {"close": {"day": 4, "time": "1600"}, "open": {"day": 4, "time": "0830"}}, {"close": {"day": 5, "time": "1600"}, "open": {"day": 5, "time": "0830"}}, {"close": {"day": 6, "time": "1600"}, "open": {"day": 6, "time": "0830"}}], "weekday_text": ["Monday: 8:30 AM \u2013 4:00 PM", "Tuesday: 8:30 AM \u2013 4:00 PM", "Wednesday: 8:30 AM \u2013 4:00 PM", "Thursday: 8:30 AM \u2013 4:00 PM", "Friday: 8:30 AM \u2013 4:00 PM", "Saturday: 8:30 AM \u2013 4:00 PM", "Sunday: 8:30 AM \u2013 4:00 PM"]}, "photos": [{"height": 5312, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/118296288152495182017/photos\">miki nogal</a>"], "photo_reference": "CmRaAAAA-r2MC6tSDKxHf
.com/maps/contrib/113176694194000645869/photos'>Mark Donohoe</a>"], "photo_reference": "CmRaAAAA5hIrcwUHN7Dp_xEoswbFH8mmfE3M1iiBJNORIx1tSfxKfwsOkZh9dD5HlCbuOzXwLC5nyUfhWTv8CUbpnxqaI5n60diEB533cgOT6xD9C_R_ibLZ6MptM-0JIohXGxwNEhB1Zk0WCr_Qh4hRX-ptiBQdGhSKE8svSlm8caZZ_bI71LPjovrSTw", "width": 3456}, {"height": 4032, "html_attributions": ["<a href='https://maps.google.com/maps/contrib/114719983703531435092/photos'>Marlene Houldsworth</a>"], "photo_reference": "CmRaAAAAnU7GxdnXJ0eskGSrt-3bj_DpizKoXvi8mjQR0O3G7r2aZPHDX0LedI1okSHBiQUI8_Xn6wmSnhj7LVabFbLcaGmSajibzZ49UpypIcltQa2h7kYT4RuLa3DcuaMkJnlPEhDxLJjRGxoJlE ...
# {\"html_attributions\": [], \"result\": {\"address_components\": [{\"long_name\": \"New York\", \"short_name\": \"New York\", \"types\": [\"locality\", \"political\"]}, {\"long_name\": \"Manhattan\", \"short_name\": \"Manhattan\", \"types\": [\"sublocality_level_1\", \"sublocality\", \"political\"]}, {\"long_name\": \"New York County\", \"short_name\": \"New York County\", \"types\": [\"administrative_area_level_2\", \"political\"]}, {\"long_name\": \"New York\", \"short_name\": \"NY\", \"types\": [\"administrative_area_level_1\", \"political\"]}, {\"long_name\": \"United States\", \"short_name\": \"US\", \"types\": [\"country\", \"political\"]}, {\"long_name\": \"10004\", \"short_name\": \"10004\", \"types\": [\"postal_code\"]}], \"adr_address\": \"<span class='locality'>New York</span>, <span class='region'>NY</span> <span class='postal-code'>10004</span>, <span class='country-name'>USA</span>\", \"formatted_address\": \"New York, NY 10004, USA\", \"formatted_phone_number\": \"(212) 363-3200\", \"geometry\": {\"location\": {\"lat\": 40.6892494, \"lng\": -74.04450039999999}, \"viewport\": {\"northeast\": {\"lat\": 40.71814749999999, \"lng\": -73.99872490000001}, \"southwest\": {\"lat\": 40.6796167, \"lng\": -74.05975889999998}}}, \"icon\": \"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png\", \"id\": \"5a0d7e67078e35af0c456a277df9ffba7c1e4da6\", \"international_phone_number\": \"+1 212-363-3200\", \"name\": \"Statue of Liberty National Monument\", \"opening_hours\": {\"open_now\": false, \"periods\": [{\"close\": {\"day\": 0, \"time\": \"1600\"}, \"open\": {\"day\": 0, \"time\": \"0830\"}}, {\"close\": {\"day\": 1, \"time\": \"1600\"}, \"open\": {\"day\": 1, \"time\": \"0830\"}}, {\"close\": {\"day\": 2, \"time\": \"1600\"}, \"open\": {\"day\": 2, \"time\": \"0830\"}}, {\"close\": {\"day\": 3, \"time\": \"1600\"}, \"open\": {\"day\": 3, \"time\": \"0830\"}}, {\"close\": {\"day\": 4, \"time\": \"1600\"}, \"open\": {\"day\": 4, \"time\": \"0830\"}}, {\"close\": {\"day\": 5, \"time\": \"1600\"}, \"open\": {\"day\": 5, \"time\": \"0830\"}}, {\"close\": {\"day\": 6, \"time\": \"1600\"}, \"open\": {\"day\": 6, \"time\": \"0830\"}}], \"weekday_text\": [\"Monday: 8:30 AM \u2013 4:00 PM\", \"Tuesday: 8:30 AM \u2013 4:00 PM\", \"Wednesday: 8:30 AM \u2013 4:00 PM\", \"Thursday: 8:30 AM \u2013 4:00 PM\", \"Friday: 8:30 AM \u2013 4:00 PM\", \"Saturday: 8:30 AM \u2013 4:00 PM\", \"Sunday: 8:30 AM \u2013 4:00 PM\"]}, \"photos\": [{\"height\": 5312, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/118296288152495182017/photos'>miki nogal</a>\"], \"photo_reference\": \"CmRaAAAA-r2MC6tSDKxHfYIuasA7QRLvrrR9pcBv46S7VKT9YC0mRy1_POzj2p_gAeMMV-udsdDh7sgAkri3ESf3LOR97eE_H6tpTxjFj5yF4hxk6zfs_G9yFy8pb5H4FsPllu2IEhCJz7N6JG0DuiY_QOVI5XPRGhRXSDhu2s5f9KOeb8BrN8ij2m6htg\", \"width\": 2988}, {\"height\": 4608, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/106265366409122628933/photos'>Isabel Casta\u00f1eda</a>\"], \"photo_reference\": \"CmRaAAAAMV7D_TqTKZfJ1hjXx9D89ifdPjPn7MmxunUn1Id1N8r3JoDaEeZt3CVB1-_H0oHZG5tWlNfNCheAL6M-pdxbajW6HJ4TVvnmmKjZAbYzza5KRcZn5PSWU_p8kELxtCvMEhBDIpRneg3eeiTT3JWSHiLcGhQAfqehQBwiZalBw3l5-D8wiNsM-w\", \"width\": 3456}, {\"height\": 2322, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/112798933856821576176/photos'>Jiasu BECERRA Y PACHECO</a>\"], \"photo_reference\": \"CmRaAAAAwH3lqtHdmCm2Ki-fdoTlcLAgKqmr_NG-yWjWn4X5LZo2ZXnzwOM9oQ7nuAjgPQdvGBZ4ONZhsKQthrSuvr_r4EsB6QPeo3Zg6KqXAFyk69k_bNmbLeq3X2rSF0rWUBDhEhDly3R-IAt_KEVGF_NCwd04GhSpM62lQl_OEBv5EVtLSrRXfZOB0A\", \"width\": 4128}, {\"height\": 5184, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/113176694194000645869/photos'>Mark Donohoe</a>\"], \"photo_reference\": \"CmRaAAAA5hIrcwUHN7Dp_xEoswbFH8mmfE3M1iiBJNORIx1tSfxKfwsOkZh9dD5HlCbuOzXwLC5nyUfhWTv8CUbpnxqaI5n60diEB533cgOT6xD9C_R_ibLZ6MptM-0JIohXGxwNEhB1Zk0WCr_Qh4hRX-ptiBQdGhSKE8svSlm8caZZ_bI71LPjovrSTw\", \"width ...

# %% [markdown]
# ### JSON Data Clean up
#
# Before we can insert JSON data into MongoDB via GraphQL, it needs some cleaning up with respect to handling of special characters like ", ' and new line.

# %%
place_details_str = json.dumps(place_details)
print(place_details_str)
temp_place_details_str = place_details_str.replace('\\\"',"'")
print(temp_place_details_str)
updated_place_details_str = temp_place_details_str.replace('"', '\\"')
print(updated_place_details_str)

# %% [markdown]
# ### Testing Insertion with Real Data
#
# Using the above insertion API, let us try to store the actual Google Places API data.

# %%
# Dynamic variable
createBaseRSPlace = gql('''
mutation createBaseRSPlace($place_id: String!, 
                           $google_place_details: JSONString!,
                           $timestamp: CustomGrapheneDateTime!) {
  create_basers_place(place_data: {place_id: $place_id, 
                                   google_place_details: $google_place_details, 
                                   timestamp: $timestamp}) {
    place_id
    ok
    message
  }
}
''')

# %%
place_id = "ChIJN1t_tDeuEmsRUsoyG83frY4"
# google_place_details = "{\"place_id\":\"ChIJN1t_tDeuEmsRUsoyG83frY4\",\"rating\" : 4.6, \"name\" : \"Google\"}".replace('"', '\\"')
# google_place_details = "{\"place_id\":\"ChIJN1t_tDeuEmsRUsoyG83frY4\",\"rating\" : 4.6, \"attri\": [{\"name\" : \"Google\"}]}".replace('"', '\\"')
google_place_details = updated_place_details_str
timestamp = "2019-06-02T13:44:31+05:30"

place_id_str = f'    "place_id": "{place_id}",\n'
google_place_details_str = f'    "google_place_details": "{google_place_details}",\n'
timestamp_str = f'    "timestamp": "{timestamp}"\n'
params = "{\n"+place_id_str+google_place_details_str+timestamp_str+"}"
print(params)
# Out:
# {
#     "place_id": "ChIJN1t_tDeuEmsRUsoyG83frY4",
#     "google_place_details": "{\"html_attributions\": [], \"result\": {\"address_components\": [{\"long_name\": \"New York\", \"short_name\": \"New York\", \"types\": [\"locality\", \"political\"]}, {\"long_name\": \"Manhattan\", \"short_name\": \"Manhattan\", \"types\": [\"sublocality_level_1\", \"sublocality\", \"political\"]}, {\"long_name\": \"New York County\", \"short_name\": \"New York County\", \"types\": [\"administrative_area_level_2\", \"political\"]}, {\"long_name\": \"New York\", \"short_name\": \"NY\", \"types\": [\"administrative_area_level_1\", \"political\"]}, {\"long_name\": \"United States\", \"short_name\": \"US\", \"types\": [\"country\", \"political\"]}, {\"long_name\": \"10004\", \"short_name\": \"10004\", \"types\": [\"postal_code\"]}], \"adr_address\": \"<span class='locality'>New York</span>, <span class='region'>NY</span> <span class='postal-code'>10004</span>, <span class='country-name'>USA</span>\", \"formatted_address\": \"New York, NY 10004, USA\", \"formatted_phone_number\": \"(212) 363-3200\", \"geometry\": {\"location\": {\"lat\": 40.6892494, \"lng\": -74.04450039999999}, \"viewport\": {\"northeast\": {\"lat\": 40.71814749999999, \"lng\": -73.99872490000001}, \"southwest\": {\"lat\": 40.6796167, \"lng\": -74.05975889999998}}}, \"icon\": \"https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png\", \"id\": \"5a0d7e67078e35af0c456a277df9ffba7c1e4da6\", \"international_phone_number\": \"+1 212-363-3200\", \"name\": \"Statue of Liberty National Monument\", \"opening_hours\": {\"open_now\": false, \"periods\": [{\"close\": {\"day\": 0, \"time\": \"1600\"}, \"open\": {\"day\": 0, \"time\": \"0830\"}}, {\"close\": {\"day\": 1, \"time\": \"1600\"}, \"open\": {\"day\": 1, \"time\": \"0830\"}}, {\"close\": {\"day\": 2, \"time\": \"1600\"}, \"open\": {\"day\": 2, \"time\": \"0830\"}}, {\"close\": {\"day\": 3, \"time\": \"1600\"}, \"open\": {\"day\": 3, \"time\": \"0830\"}}, {\"close\": {\"day\": 4, \"time\": \"1600\"}, \"open\": {\"day\": 4, \"time\": \"0830\"}}, {\"close\": {\"day\": 5, \"time\": \"1600\"}, \"open\": {\"day\": 5, \"time\": \"0830\"}}, {\"close\": {\"day\": 6, \"time\": \"1600\"}, \"open\": {\"day\": 6, \"time\": \"0830\"}}], \"weekday_text\": [\"Monday: 8:30 AM \u2013 4:00 PM\", \"Tuesday: 8:30 AM \u2013 4:00 PM\", \"Wednesday: 8:30 AM \u2013 4:00 PM\", \"Thursday: 8:30 AM \u2013 4:00 PM\", \"Friday: 8:30 AM \u2013 4:00 PM\", \"Saturday: 8:30 AM \u2013 4:00 PM\", \"Sunday: 8:30 AM \u2013 4:00 PM\"]}, \"photos\": [{\"height\": 5312, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/118296288152495182017/photos'>miki nogal</a>\"], \"photo_reference\": \"CmRaAAAA-r2MC6tSDKxHfYIuasA7QRLvrrR9pcBv46S7VKT9YC0mRy1_POzj2p_gAeMMV-udsdDh7sgAkri3ESf3LOR97eE_H6tpTxjFj5yF4hxk6zfs_G9yFy8pb5H4FsPllu2IEhCJz7N6JG0DuiY_QOVI5XPRGhRXSDhu2s5f9KOeb8BrN8ij2m6htg\", \"width\": 2988}, {\"height\": 4608, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/106265366409122628933/photos'>Isabel Casta\u00f1eda</a>\"], \"photo_reference\": \"CmRaAAAAMV7D_TqTKZfJ1hjXx9D89ifdPjPn7MmxunUn1Id1N8r3JoDaEeZt3CVB1-_H0oHZG5tWlNfNCheAL6M-pdxbajW6HJ4TVvnmmKjZAbYzza5KRcZn5PSWU_p8kELxtCvMEhBDIpRneg3eeiTT3JWSHiLcGhQAfqehQBwiZalBw3l5-D8wiNsM-w\", \"width\": 3456}, {\"height\": 2322, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/112798933856821576176/photos'>Jiasu BECERRA Y PACHECO</a>\"], \"photo_reference\": \"CmRaAAAAwH3lqtHdmCm2Ki-fdoTlcLAgKqmr_NG-yWjWn4X5LZo2ZXnzwOM9oQ7nuAjgPQdvGBZ4ONZhsKQthrSuvr_r4EsB6QPeo3Zg6KqXAFyk69k_bNmbLeq3X2rSF0rWUBDhEhDly3R-IAt_KEVGF_NCwd04GhSpM62lQl_OEBv5EVtLSrRXfZOB0A\", \"width\": 4128}, {\"height\": 5184, \"html_attributions\": [\"<a href='https://maps.google.com/maps/contrib/113176694194000645869/photos'>Mark Donohoe</a>\"], \"photo_reference\": \"CmRaAAAA5hIrcwUHN7Dp_xEoswbFH8mmfE3M1iiBJNORIx1tSfxKfwsOkZh9dD5HlCbuOzXwLC5nyUfhWTv8CUbpnxqaI5n60diEB533cgOT6xD9C_R_ibLZ6MptM-0JIohXGxwNEhB1Zk0WCr_Qh4hRX-ptiBQdGhSKE8svSlm8 ...
#     "timestamp": "2019-06-02T13:44:31+05:30"
# }

# %%
client.execute(createBaseRSPlace, variable_values=params)
# Out:
# {'create_basers_place': {'message': 'Success',
#   'ok': True,
#   'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'}}

# %% [markdown]
# ### Verifying the Insertion
#
# Let us verify if the data was successfully stored by trying to fetch the details using previously mentioned APIs for retrieveing all Places IDs and specific Place Details.
#
# Also to ensure the data is parsable, we shall use json.loads to check the data consistency.

# %%
client.execute(queryBaseRSAllPlaceIDs)
# Out:
# {'basers_all_place_ids': [{'place_id': 'ChIJbf8C1yFxdDkR3n12P4DkKt0'},
#   {'place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA'},
#   {'place_id': 'ChIJuU2C7F5E04kRiKK9VmHF0kY'},
#   {'place_id': 'ChIJrwO1fgcmMxURNKNBOlKTnJw'},
#   {'place_id': 'ChIJaXQRs6lZwokRY6EFpJnhNNE'},
#   {'place_id': 'ChIJN1t_tDeuEmsRUsoyG83frY4'}]}

# %%
response = client.execute(queryBaseRSPlaceDetails, variable_values=params)

# %%
json.loads(response['basers_place_details']['google_place_details'])

# %%
def get_place_details(place_id):
    # Dynamic variable
    queryBaseRSPlaceDetails = gql('''
    query queryBaseRSPlaceDetails($place_id: String!) {
      basers_place_details(place_id: $place_id) {
        place_id
        google_place_details
      }
    }
    ''')
    
    # Creating dynamic parameter list
    place_id_str = f'    "place_id": "{place_id}"\n'  # noqa: E999
    params = "{\n"+place_id_str+"}"

    return client.execute(queryBaseRSPlaceDetails, variable_values=params)

# %%
import pprint
pp = pprint.PrettyPrinter()

queryBaseRSAllPlaceIDs = gql('''
query queryBaseRSAllPlaceIDs {
  basers_all_place_ids{
    place_id
  }
}
''')

result = client.execute(queryBaseRSAllPlaceIDs)
all_place_info = result['basers_all_place_ids']

for place_info in all_place_info:
    place_id = place_info['place_id']
    print(f"Fetching place details for {place_id}...")
    place_details_result = get_place_details(place_id)
    place_details = place_details_result['basers_place_details']['google_place_details']
    pp.pprint(json.loads(place_details))
# Out:
# Fetching place details for ChIJbf8C1yFxdDkR3n12P4DkKt0...
# {'address_components': [{'long_name': 'Dharmapuri',
#                          'short_name': 'Dharmapuri',
#                          'types': ['neighborhood', 'political']},
#                         {'long_name': 'Forest Colony',
#                          'short_name': 'Forest Colony',
#                          'types': ['sublocality_level_2',
#                                    'sublocality',
#                                    'political']},
#                         {'long_name': 'Tajganj',
#                          'short_name': 'Tajganj',
#                          'types': ['sublocality_level_1',
#                                    'sublocality',
#                                    'political']},
#                         {'long_name': 'Agra',
#                          'short_name': 'Agra',
#                          'types': ['locality', 'political']},
#                         {'long_name': 'Agra',
#                          'short_name': 'Agra',
#                          'types': ['administrative_area_level_2', 'political']},
#                         {'long_name': 'Uttar Pradesh',
#                          'short_name': 'UP',
#                          'types': ['administrative_area_level_1', 'political']},
#                         {'long_name': 'India',
#                          'short_name': 'IN',
#                          'types': ['country', 'political']},
#                         {'long_name': '282001',
#                          'short_name': '282001',
#                          'types': ['postal_code']}],
#  'adr_address': "<span class='extended-address'>Dharmapuri, Forest Colony, "
#                 "Tajganj</span>, <span class='locality'>Agra</span>, <span "
#                 "class='region'>Uttar Pradesh</span> <span "
#                 "class='postal-code'>282001</span>, <span "
#                 "class='country-name'>India</span>",
#  'formatted_address': 'Dharmapuri, Forest Colony, Tajganj, Agra, Uttar Pradesh '
#                       '282001, India',
#  'formatted_phone_number': '0562 222 7261',
#  'geometry': {'location': {'lat': 27.1751448, 'lng': 78.0421422},
#               'viewport': {'northeast': {'lat': 27.1772325,
#                                          'lng': 78.04546859999999},
#                            'southwest': {'lat': 27.1688817,
#                                          'lng': 78.03880380000001}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons
s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 months ago',
#               'text': "Beautiful, just how you'd expect it to be. It is, after "
#                       'all, one of the 7 wonders of the world. There are '
#                       'beautiful gardens all around where you can roam, and '
#                       'there 4 gates to enter from. The general ticket is 50 '
#                       'bucks and the high value ticket is for 250. The '
#                       'difference is that with the high value ticket you can '
#                       "go up there on the platform :) I'd recommend you do "
#                       'take the 250 one because the pictures with the white '
#                       'marble-y background are unmatched. Great place for '
#                       'visiting. Have fun!\n'
#                       "It's most beautiful place. Traveller should try to make "
#                       'it to see sunset at Taj Mahal as well as experience the '
#                       'sunrise view. The early you visit monument less crown u '
#                       'experience and one can enjoy clicking pictures. Be '
#                       'careful of the guides that are in the monuments. It is '
#                       'not mandatory to have guide, nor is it required. One '
#                       'can read online about the monument and enjoy guide free '
#                       'own way the monuments.',
#               'time': 1559037932},
#              {'author_name': 'Technews Shubham gaud',
#               'author_url': 'https://www.google.com/maps/contrib/109186276645473585852/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-aSeuRbbpAP4/AAAAAAAAAAI/AAAAAAAAFFs/S971f1dv6xg/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 months ago',
#               'text': "Beautiful, just how you'd expect it to be. It is, after "
#                       'all, one of the 7 wonders of the world. There are '
#                       'beautiful gardens all around where you can roam, and '
#                       'there 4 gates to enter from. The general ticket is 50 '
#                       'bucks and the high value ticket is for 250. The '
#                       'difference is that with the high value ticket you can '
#                       "go up there on the platform :) I'd recommend you do "
#                       'take the 250 one because the pictures with the white '
#                       'marble-y background are unmatched. Great place for '
#                       'visiting. Have fun!\n'
#                       "It's most beautiful place. Traveller should try to make "
#                       'it to see sunset at Taj Mahal as well as experience the '
#                       'sunrise view. The early you visit monument less crown u '
#                       'experience and one can enjoy clicking pictures. Be '
#                       'careful of the guides that are in the monuments. It is '
#                       'not mandatory to have guide, nor is it required. One '
#                       'can read online about the monument and enjoy guide free '
#                       'own way the monuments',
#               'time': 1558193770},
#              {'author_name': 'Vinay Raj',
#               'author_url': 'https://www.google.com/maps/contrib/110672869747083176137/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh6.googleusercontent.com/-DP5VUgoba8M/AAAAAAAAAAI/AAAAAAAAABM/NpFdj8LGO6I/s128-c0x00000000-cc-rp-mo-ba6/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 months ago',
#               'text': "Beautiful, just how you'd expect it to be. It is, after "
#                       'all, one of the 7 wonders of the world. There are '
#                       'beautiful gardens all around where you can roam, and '
#                       'there 4 gates to enter from. The general ticket is 50 '
#                       'bucks and the high value ticket is for 250. The '
#                       'difference is that with the high value ticket you can '
#                       "go up there on the platform :) I'd recommend you do "
#                       'take the 250 one because the pictures with the white '
#                       'marble-y background are unmatched. Great place for '
#                       'visiting. Have fun!\n'
#                       "It's most beautiful place. Traveller should try to make "
#                       'it to see sunset at Taj Mahal as well as experience the '
#                       'sunrise view. The early you visit monument less crown u '
#                       'experience and one can enjoy clicking pictures. Be '
#                       'careful of the guides that are in the monuments. It is '
#                       'not mandatory to have guide, nor is it required. One '
#                       'can read online about the monument and enjoy guide free '
#                       'own way the monuments.',
#               'time': 1558153981},
#              {'author_name': 'SUJAN PRAKASH',
#               'author_url': 'https://www.google.com/maps/contrib/107593497481244770684/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh6.googleusercontent.com/-NVbWc1i2RLE/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rf7kFqQR2yGdudVjhQVO929XxKl-w/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 months ago',
#               'text': "Beautiful, just how you'd expect it to be. It is, after "
#                       'all, one of the 7 wonders of the world. There are '
#                       'beautiful gardens all around where you can roam, and '
#                       'there 4 gates to enter from. The general ticket is 50 '
#                       'bucks and the high value ticket is for 250. The '
#                       'difference is that with the high value ticket you can '
#                       "go up there on the platform :) I'd recommend you do "
#                       'take the 250 one because the pictures with the white '
#                       'marble-y background are unmatched. Great place for '
#                       'visiting. Have fun!\n'
#                       "It's most beautiful place. Traveller should try to make "
#                       'it to see sunset at Taj Mahal as well as experience the '
#                       'sunrise view. The early you visit monument less crown u '
#                       'experience and one can enjoy clicking pictures. Be '
#                       'careful of the guides that are in the monuments. It is '
#                       'not mandatory to have guide, nor is it required. One '
#                       'can read online about the monument and enjoy guide free '
#                       'own way the monuments',
#               'time': 1557811776},
#              {'author_name': 'Anas Nizam',
#               'author_url': 'https://www.google.com/maps/contrib/107398728548120178003/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh4.googleusercontent.com/-uZP3A2Z9DGU/AAAAAAAAAAI/AAAAAAAAACE/3cvQzza0pmI/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 months ago',
#               'text': "Beautiful, just how you'd expect it to be. It is, after "
#                       'all, one of the 7 wonders of the world. There are '
#                       'beautiful gardens all around where you can roam, and '
#                       'there 4 gates to enter from. The general ticket is 50 '
#                       'bucks and the high value ticket is for 250. The '
#                       'difference is that with the high value ticket you can '
#                       "go up there on the platform :) I'd recommend you do "
#                       'take the 250 one because the pictures with the white '
#                       'marble-y background are unmatched. Great place for '
#                       'visiting. Have fun!\n'
#                       "It's most beautiful place. Traveller should try to make "
#                       'it to see sunset at Taj Mahal as well as experience the '
#                       'sunrise view. The early you visit monument less crown u '
#                       'experience and one can enjoy clicking pictures. Be '
#                       'careful of the guides that are in the monuments. It is '
#                       'not mandatory to have guide, nor is it required. One '
#                       'can read online about the monument and enjoy guide free '
#                       'own way the monuments.',
#               'time': 1557927174}],
#  'scope': 'GOOGLE',
#  'types': ['point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=15936801470875598302',
#  'user_ratings_total': 160180,
#  'utc_offset': 330,
#  'vicinity': 'Dharmapuri, Forest Colony, Tajganj, Agra',
#  'website': 'https://www.tajmahal.gov.in/'}
# Fetching place details for ChIJPTacEpBQwokRKwIlDXelxkA...
# {'address_components': [{'long_name': 'New York',
#                          'short_name': 'New York',
#                          'types': ['locality', 'political']},
#                         {'long_name': 'Manhattan',
#                          'short_name': 'Manhattan',
#                          'types': ['sublocality_level_1',
#                                    'sublocality',
#                                    'political']},
#                         {'long_name': 'New York County',
#                          'short_name': 'New York County',
#                          'types': ['administrative_area_level_2', 'political']},
#                         {'long_name': 'New York',
#                          'short_name': 'NY',
#                          'types': ['administrative_area_level_1', 'political']},
#                         {'long_name': 'United States',
#                          'short_name': 'US',
#                          'types': ['country', 'political']},
#                         {'long_name': '10004',
#                          'short_name': '10004',
#                          'types': ['postal_code']}],
#  'adr_address': "<span class='locality'>New York</span>, <span "
#                 "class='region'>NY</span> <span "
#                 "class='postal-code'>10004</span>, <span "
#                 "class='country-name'>USA</span>",
#  'formatted_address': 'New York, NY 10004, USA',
#  'formatted_phone_number': '(212) 363-3200',
#  'geometry': {'location': {'lat': 40.6892494, 'lng': -74.04450039999999},
#               'viewport': {'northeast': {'lat': 40.71814749999999,
#                                          'lng': -73.99872490000001},
#                            'southwest': {'lat': 40.6796167,
#                                          'lng': -74.05975889999998}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#  'id': '5a0d7e67078e35af0c456a277df9ffba7c1e4da6',
#  'international_phone_number': '+1 212-363-3200',
#  'name': 'Statue of Liberty National Monument',
#  'opening_hours': {'open_now': False,
#                    'periods': [{'close': {'day': 0, 'time': '1600'},
#                                 'open': {'day': 0, 'time': '0830'}},
#                                {'close': {'day': 1, 'time': '1600'},
#                                 'open': {'day': 1, 'time': '0830'}},
#                                {'close': {'day': 2, 'time': '1600'},
#                                 'open': {'day': 2, 'time': '0830'}},
#                                {'close': {'day': 3, 'time': '1600'},
#                                 'open': {'day': 3, 'time': '0830'}},
#                                {'close': {'day': 4, 'time': '1600'},
#                                 'open': {'day': 4, 'time': '0830'}},
#                                {'close': {'day': 5, 'time': '1600'},
#                                 'open': {'day': 5, 'time': '0830'}},
#                                {'close': {'day': 6, 'time': '1600'},
#                                 'open': {'day': 6, 'time': '0830'}}],
#                    'weekday_text': ['Monday: 8:30 AM – 4:00 PM',
#                                     'Tuesday: 8:30 AM – 4:00 PM',
#                                     'Wednesday: 8:30 AM – 4:00 PM',
#                                     'Thursday: 8:30 AM – 4:00 PM',
#                                     'Friday: 8:30 AM – 4:00 PM',
#                                     'Saturday: 8:30 AM – 4:00 PM',
#                                     'Sunday: 8:30 AM – 4:00 PM']},
#  'photos': [{'height': 1224,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/111479359569644610667/photos'>Miryan "
#                                    'O. Rodríguez</a>'],
#              'photo_reference': 'CmRaAAAAsFEa5ScNIhDhB3sGjR1xo4nDUr3O6xnDK-5XwGv_ijSxgqzxqBu3C3tmJVt44VTAo_hzlXcllpcelnjLVkdbfmzh-NsNqGRLJX5AZE06Q4vkBFGOpiWv3MTQ2HHnepD3EhA5ECFHiy9HFxOxKduehMSxGhS0r03JwIvDSUIMIOh-53E0ZY1lmw',
#              'width': 720},
#             {'height': 4032,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/109362486134666109774/photos'>Phaedra "
#                                    'Culley</a>'],
#              'photo_reference': 'CmRaAAAAmUp6JUjxLO7BAA8CapPy2i4fEuIegBP9WdFzq6WRB7Prh54EesVjZ_9f8Iis-YCvOOVlzTg80k6ZmVALfNltavkgA3opdZQIjOe4IqARHey2uKZVCJgottLXKM-XTSQBEhBqSYD3q9Y_gZs_4P2V45IKGhQaqdhAxnH31Wiu75gsfbQYXNhKGA',
#              'width': 3024},
#             {'height': 2322,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/112798933856821576176/photos'>Jiasu "
#                                    'BECERRA Y PACHECO</a>'],
#              'photo_reference': 'CmRaAAAA8Pt_cf3gzt6oppRvlQhTt1Y8NfZJsIdozHMJMEApTaR3C2QQQB7fFCDhHi4XVajX4OBZZiG_EWdzdSl5fDidpK8zGQemNcA-wBAF2zjWmwSHa64RSrk6dXL4BgBDobeuEhADQV-WPYj88WVmfeeaZVuWGhQxSrQssrGSaGfKOjHroZzLc6QM1g',
#              'width': 4128},
#             {'height': 5184,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib

#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/111177214989513874707/photos'>Beny "
#                                    'Jackson</a>'],
#              'photo_reference': 'CmRaAAAApBYFyK-jENGzmAxv5X2R3G72oL1mgaNyvvITuZBou7nkrPRhAgYC99OekZ_yHcKch2xpiuGGzSu8cn88QztwSUW2uGnC78wFyCkZfdq1uupX3Flkfq_NjUYUNe8RvVDaEhBJL60hRUyVkSXrG5AT8PyHGhQp8uwLQ7V7bMnZMTeO0rPpW5Vhqw',
#              'width': 3456}],
#  'place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#  'plus_code': {'compound_code': 'MXQ4+M5 New York, United States',
#                'global_code': '87G7MXQ4+M5'},
#  'rating': 4.6,
#  'reference': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#  'reviews': [{'author_name': 'Keith Roussel',
#               'author_url': 'https://www.google.com/maps/contrib/102940353216229364374/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh4.googleusercontent.com/-Ft8-RVxtvZw/AAAAAAAAAAI/AAAAAAAAGCg/5URczFjPNNw/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a week ago',
#               'text': 'I have seen photos of it all my life and was delighted '
#                       'to finally visit this great symbol of liberty. I was '
#                       'able to obtain tickets with pedestal access the night '
#                       'before. Buy tickets direct from Statue Cruises because '
#                       'all other sites seem to charge as much as 30% more. You '
#                       "don't need to show up more than 15-30 minutes before "
#                       "your ferry's departure. Be prepared to go through a "
#                       'security checkpoint before boarding. If you have '
#                       'pedestal or crown access you will need to leave '
#                       'backpacks and drinks in a locker at the base of the '
#                       'statue. Take photos of the Statue as you are cruising '
#                       'to it and take photos of Manhattan as you return. There '
#                       'are so many great views. I took the stairs up tot he '
#                       'pedestal instead of the elevator. Even with my bad '
#                       'knees I was easily able to handle it. The pedestal '
#                       'balcony is very slim, so it can get crowded quickly. '
#                       'There is a nice museum to visit that discusses the '
#                       'history and construction of the statue.',
#               'time': 1564103249},
#              {'author_name': 'NotAYT',
#               'author_url': 'https://www.google.com/maps/contrib/109843756268742366896/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh4.googleusercontent.com/-LQO3i-u6w90/AAAAAAAAAAI/AAAAAAAAHgo/FpfS5cMzMig/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a week ago',
#               'text': 'Wonderful tribute to freedom! I loved the video series. '
#                       "The history of the artist's idea, its development and "
#                       'actualization is much different than common stories. '
#                       'The concept of placing a massive Lady with the Torch of '
#                       'Freedom in America by New York City came to the artist '
#                       'amid the French revolution and from a dearth of human '
#                       'freedom around the world. His hope was that placing his '
#                       'Statue of Liberty where it is would spread liberty and '
#                       'human freedom throughout the world. Wonderful '
#                       'experience.',
#               'time': 1563892911},
#              {'author_name': 'Katie Castaldi',
#               'author_url': 'https://www.google.com/maps/contrib/103760909276755106225/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-JCNiCYCEUe0/AAAAAAAAAAI/AAAAAAAApUU/_L5EyjbYPw0/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a week ago',
#               'text': "SO COOL! She's so iconic so it was truly amazing to be "
#                       'right there to see her. We paid extra to go up the '
#                       "pedestal and it was neat! You can't see her better but "
#                       'your view of Manhattan,  etc is better.  You also get '
#                       'to see up inside the statute. \n'
#                       'Truly humbling to think what this beacon meant to our '
#                       'ancestors.  To finally see here after weeks on a boat. '
#                       'A view that meant freedom was near!',
#               'time': 1563629088},
#              {'author_name': 'Kevin Gifford',
#               'author_url': 'https://www.google.com/maps/contrib/110973769215261937975/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh6.googleusercontent.com/-fy4u48O0pU4/AAAAAAAAAAI/AAAAAAAAAHU/roGyZ-G5OQ4/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '3 weeks ago',
#               'text': 'Wonderful tribute to freedom! I loved the video series. '
#                       "The history of the artist's idea, its development and "
#                       'actualization is much different than common stories. '
#                       'The concept of placing a massive Lady with the Torch of '
#                       'Freedom in America by New York City came to the artist '
#                       'amid the French revolution and from a dearth of human '
#                       'freedom around the world. His hope was that placing his '
#                       'Statue of Liberty where it is would spread liberty and '
#                       'human freedom throughout the world. Wonderful '
#                       'experience.',
#               'time': 1562957169},
#              {'author_name': 'chinnivanaja krishna',
#               'author_url': 'https://www.google.com/maps/contrib/101985455672705108750/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh6.googleusercontent.com/-XqhxbLA225Y/AAAAAAAAAAI/AAAAAAACQVo/qv95tWaMv0s/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'in the last week',
#               'text': 'What does the torch represent?\xa0The torch is a symbol '
#                       "of enlightenment. The Statue of Liberty's torch lights "
#                       'the way to freedom showing us the path to Liberty. Even '
#                       "the Statue's official name represents her most "
#                       "important symbol 'Liberty Enlightening the World'. The "
#                       "Statue's current replacement torch, added in 1986, is a "
#                       'copper flame covered in 24K gold. It is reflective of '
#                       "the sun's rays in daytime and lighted by 16 floodlights "
#                       'at night. The original torch was removed in 1984 and is '
#                       'currently inside the lobby of the monument.',
#               'time': 1564589412}],
#  'scope': 'GOOGLE',
#  'types': ['park', 'point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=4667599994556318251',
#  'user_ratings_total': 55418,
#  'utc_offset': -240,
#  'vicinity': 'New York',
#  'website': 'https://www.nps.gov/stli/index.htm'}
# Fetching place details for ChIJuU2C7F5E04kRiKK9VmHF0kY...
# {'address_components': [{'long_name': 'Niagara Falls',
#                          'short_name': 'Niagara Falls',
#                          'types': ['locality', 'political']},
#                         {'long_name': 'Grand Island',
#                          'short_name': 'Grand Island',
#                          'types': ['administrative_area_level_3', 'political']},
#                         {'long_name': 'Regional Municipality of Niagara',
#                          'short_name': 'Regional Municipality of Niagara',
#                          'types': ['administrative_area_level_2', 'political']},
#                         {'long_name': 'Ontario',
#                          'short_name': 'ON',
#                          'types': ['administrative_area_level_1', 'political']},
#                         {'long_name': 'Canada',
#                          'short_name': 'CA',
#                          'types': ['country', 'political']}],
#  'adr_address': "<span class='locality'>Niagara Falls</span>, <span "
#                 "class='region'>ON</span>, <span "
#                 "class='country-name'>Canada</span>",
#  'formatted_address': 'Niagara Falls, ON, Canada',
#  'geometry': {'location': {'lat': 43.0895577, 'lng': -79.0849436},
#               'viewport': {'northeast': {'lat': 43.148289, 'lng': -78.999667},
#                            'southwest': {'lat': 42.95957600000001,
#                                          'lng': -79.17640209999999}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#  'id': '83599a7b6827bfc557d409ae8236cb2df8db31e1',
#  'name': 'Niagara Falls',
#  'photos': [{'height': 768,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib

#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/116994157227707376536/photos'>Roger "
#                                    'Madore</a>'],
#              'photo_reference': 'CmRaAAAAKTRe_yncHCZuiNugG6LrVnhcEKxERHWZgJ7HHCdRm9s4T9zHyN3vWOcmZSIcuDbQe1jNTvQF1wj420cEl3zVcma3MFJVZ7ea3JyJIIPT5YosKVJofeREVqne2cP9LbwYEhA44S1OD6OEVPJkwyAKmseIGhRYPBA_5qqYJUcXCB8L-bxxyo6pjw',
#              'width': 4032},
#             {'height': 3024,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/111912710009716395487/photos'>Michael "
#                                    'J Procopio</a>'],
#              'photo_reference': 'CmRaAAAAwC6OEd9Wrx0bjnHJq9HRfczzuphkxFMQZY7p55OOfSOsvLYLX5dr3NUoSCQ-xYGJgmosvLymVVCbjuP4fD4T34NmI31-qu3UB9a7-NscmlyiJEl4QB8OiAlQ_bB90v-iEhAREDtEtifMfIfXNFkYumYWGhR5VaA-YPCixH2XhhpQQVsqhHL_qw',
#              'width': 4032},
#             {'height': 3096,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/117261092179239879358/photos'>Fred "
#                                    'Stock</a>'],
#              'photo_reference': 'CmRaAAAATw3frJ1DxoUCGqsiYJhSIB1i3dlzRS0eFFdb0cYPmi7cK3KHLytkPRWz6Ibo8R4CjVjy8977BblOMzz8jtoeQ2FYMt4uk_5UFtAwJXGC5jQoXd3n9K02NQURxsfQJOgXEhBD82l0WAMjv7P0WdFQBk2VGhQitoqDTspBWcSexnF0RpmsPOmKgA',
#              'width': 4128},
#             {'height': 2432,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/115883700377935385157/photos'>Becky "
#                                    'Robinson</a>'],
#              'photo_reference': 'CmRaAAAAfPpR0WZ8QydGANqt_iS2aGZIuC1CPbncaY5hu-SNaZla-YdTrlibfYNfcyirAB4pfpz6QPM1ZR_lRmQKc_Mgc-fv9kn5W6a_rPVLqo48EEJncnX_Xq-Rx9yidXKC-R-IEhAW8E5cg3SFXc3YtSpRFmAVGhS0TBwt-J6GqUNnn-GCX5qeb3fZRg',
#              'width': 4320}],
#  'place_id': 'ChIJuU2C7F5E04kRiKK9VmHF0kY',
#  'reference': 'ChIJuU2C7F5E04kRiKK9VmHF0kY',
#  'scope': 'GOOGLE',
#  'types': ['locality', 'political'],
#  'url': 'https://maps.google.com/?q=Niagara+Falls,+ON,+Canada&ftid=0x89d3445eec824db9:0x46d2c56156bda288',
#  'utc_offset': -240,
#  'vicinity': 'Niagara Falls',
#  'website': 'http://www.niagarafalls.ca/'}
# Fetching place details for ChIJrwO1fgcmMxURNKNBOlKTnJw...
# {'address_components': [{'long_name': '3701',
#                          'short_name': '3701',
#                          'types': ['street_number']},
#                         {'long_name': 'Mallard Drive',
#                          'short_name': 'Mallard Dr',
#                          'types': ['route']},
#                         {'long_name': 'Benicia',
#                          'short_name': 'Benicia',
#                          'types': ['locality', 'political']},
#                         {'long_name': 'Solano County',
#                          'short_name': 'Solano County',
#                          'types': ['administrative_area_level_2', 'political']},
#                         {'long_name': 'California',
#                          'short_name': 'CA',
#                          'types': ['administrative_area_level_1', 'political']},
#                         {'long_name': 'United States',
#                          'short_name': 'US',
#                          'types': ['country', 'political']},
#                         {'long_name': '94510',
#                          'short_name': '94510',
#                          'types': ['postal_code']},
#                         {'long_name': '1195',
#                          'short_name': '1195',
#                          'types': ['postal_code_suffix']}],
#  'adr_address': "<span class='street-address'>3701 Mallard Dr</span>, <span "
#                 "class='locality'>Benicia</span>, <span "
#                 "class='region'>CA</span> <span "
#                 "class='postal-code'>94510-1195</span>, <span "
#                 "class='country-name'>USA</span>",
#  'formatted_address': '3701 Mallard Dr, Benicia, CA 94510, USA',
#  'formatted_phone_number': '(925) 372-8000',
#  'geometry': {'location': {'lat': 38.0684823, 'lng': -122.1260364},
#               'viewport': {'northeast': {'lat': 38.06967108029149,
#                                          'lng': -122.1244618197085},
#                            'southwest': {'lat': 38.0669731197085,
#                                          'lng': -122.1271597802915}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#  'id': '8fa8931b128221fe9d49bc38cef47c37e834e622',
#  'international_phone_number': '+1 925-372-8000',
#  'name': 'Golden State Bridge Inc',
#  'place_id': 'ChIJrwO1fgcmMxURNKNBOlKTnJw',
#  'plus_code': {'compound_code': '3V9F+9H Benicia, California, United States',
#                'global_code': '84CV3V9F+9H'},
#  'rating': 4.5,
#  'reference': 'ChIJrwO1fgcmMxURNKNBOlKTnJw',
#  'reviews': [{'author_name': 'Eddie Chris',
#               'author_url': 'https://www.google.com/maps/contrib/103807610968306424740/reviews',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-G8vXUOaYJs4/AAAAAAAAAAI/AAAAAAAAHBo/nkSurszeJJo/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a year ago',
#               'text': '',
#               'time': 1530101858},
#              {'author_name': 'Ramon Silva',
#               'author_url': 'https://www.google.com/maps/contrib/106148280416382718813/reviews',
#               'profile_photo_url': 'https://lh6.googleusercontent.com/-gwPFZQIb6C4/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rf9C6jfsQI1qiMEU3j0pJKZO4tT3Q/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 4,
#               'relative_time_description': '2 years ago',
#               'text': '',
#               'time': 1480084396}],
#  'scope': 'GOOGLE',
#  'types': ['point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=11285056747657601844',
#  'user_ratings_total': 2,
#  'utc_offset': -420,
#  'vicinity': '3701 Mallard Drive, Benicia',
#  'website': 'http://gsbridge.com/'}
# Fetching place details for ChIJaXQRs6lZwokRY6EFpJnhNNE...
# {'address_components': [{'long_name': '20',
#                          'short_name': '20',
#                          'types': ['street_number']},
#                         {'long_name': 'West 34th Street',
#                          'short_name': 'W 34th St',
#                          'types': ['route']},
#                         {'long_name': 'Manhattan',
#                          'short_name': 'Manhattan',
#                          'types': ['sublocality_level_1',
#                                    'sublocality',
#                                    'political']},
#                         {'long_name': 'New York',
#                          'short_name': 'New York',
#                          'types': ['locality', 'political']},
#                         {'long_name': 'New York County',
#                          'short_name': 'New York County',
#                          'types': ['administrative_area_level_2', 'political']},
#                         {'long_name': 'New York',
#                          'short_name': 'NY',
#                          'types': ['administrative_area_level_1', 'political']},
#                         {'long_name': 'United States',
#                          'short_name': 'US',
#                          'types': ['country', 'political']},
#                         {'long_name': '10001',
#                          'short_name': '10001',
#                          'types': ['postal_code']}],
#  'adr_address': "<span class='street-address'>20 W 34th St</span>, <span "
#                 "class='locality'>New York</span>, <span "
#                 "class='region'>NY</span> <span "
#                 "class='postal-code'>10001</span>, <span "
#                 "class='country-name'>USA</span>",
#  'formatted_address': '20 W 34th St, New York, NY 10001, USA',
#  'formatted_phone_number': '(212) 736-3100',
#  'geometry': {'location': {'lat': 40.7484405, 'lng': -73.98566439999999},
#               'viewport': {'northeast': {'lat': 40.7497105802915,
#                                          'lng': -73.98392536970849},
#                            'southwest': {'lat': 40.7470126197085,
#                                          'lng': -73.98662333029151}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#  'id': 'bc232d2422e7068b2a2ffb314f02e3733dd47796',
#  'international_phone_number': '+1 212-736-3100',
#  'name': 'Empire State Building',
#  'opening_hours': {'open_now': True,
#                    'periods': [{'close': {'day': 1, 'time': '0200'},
#                                 'open': {'day': 0, 'time': '0800'}},
#                                {'close': {'day': 2, 'time': '0200'},
#                                 'open': {'day': 1, 'time': '0800'}},
#                                {'close': {'day': 3, 'time': '0200'},
#                                 'open': {'day': 2, 'time': '0800'}},
#                                {'close': {'day': 4, 'time': '0200'},
#                                 'open': {'day': 3, 'time': '0800'}},
#                                {'close': {'day': 5, 'time': '0200'},
#                                 'open': {'day': 4, 'time': '0800'}},
#                                {'close': {'day': 6, 'time': '0200'},
#                                 'open': {'day': 5, 'time': '0800'}},
#                                {'close': {'day': 0, 'time': '0200'},
#                                 'open': {'day': 6, 'time': '0800'}}],
#                    'weekday_text': ['Monday: 8:00 AM – 2:00 AM',
#                                     'Tuesday: 8:00 AM – 2:00 AM',
#                                     'Wednesday: 8:00 AM – 2:00 AM',
#                                     'Thursday: 8:00 AM – 2:00 AM',
#                                     'Friday: 8:00 AM – 2:00 AM',
#                                     'Saturday: 8:00 AM – 2:00 AM',
#                                     'Sunday: 8:00 AM – 2:00 AM']},
#  'photos': [{'height': 3024,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/101129828639082815884/photos'>E "
#                                    'Scott Parks</a>'],
#              'photo_reference': 'CmRaAAAAJ4ba0GYK5BenNUDPwHRlaR5s0f8EXv1f52xoEP_UUblXxwkBU2u7io0fp1FSTSiXmTD5HqsQqlHSxU7fIORUqUkQWvWg9pthIOkP8ns9q7nWrl4F1-WjBRdFCIfuMT6fEhAs9idoXBhE2fBdFJit1fBiGhQEG86h9Yu6Q-v2Ca2j4hALhYjhWw',
#              'width': 4032},
#             {'height': 4640,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/104391030199786871848/photos'>sonja "
#                                    'jamilla</a>'],
# ...
#                       'breezy and had great views. There is a glass in the '
#                       'middle so you can safely look down the center of the '
#                       'tower.  Visitors go according to a time slot. No bags '
#                       'allowed on the tower.',
#               'time': 1564495089},
#              {'author_name': 'KS Hepler',
#               'author_url': 'https://www.google.com/maps/contrib/117420994702716240025/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh6.googleusercontent.com/-FPDqjM16emI/AAAAAAAAAAI/AAAAAAAAAA0/iGLSUPlTKYE/s128-c0x00000000-cc-rp-mo/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a week ago',
#               'text': 'Was beautiful and amazing at the same time! It’s an '
#                       'unforgettable vacation. Lots of pictures to take. It '
#                       'wasn’t so crowded that you couldn’t see everything '
#                       'there. We went in May and the weather was beautiful, no '
#                       'rain ☔️. I would definitely recommend this place to '
#                       'anyone going to Italy 🇮🇹',
#               'time': 1563760624},
#              {'author_name': 'Shrina Desai',
#               'author_url': 'https://www.google.com/maps/contrib/116366183152124837323/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-zbYwfV6rpYc/AAAAAAAAAAI/AAAAAAAAAto/Luq1JuSg2iU/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a month ago',
#               'text': 'A must see if you’re ever in Pisa. The info center is '
#                       'very helpful. I booked my ticket to climb to the top of '
#                       'the tower before I went but I saw people making '
#                       'reservations in person at the counter. They have secure '
#                       'areas to place your belongings since you can’t take '
#                       'them in the tower. The system was very easy and it was '
#                       'not a hassle to put out belongings in the locker and '
#                       'retrieve them again. There is a guide at the bottom of '
#                       'the tower that gives a little info and then you’re on '
#                       'your own to climb the steps and explore the top. You '
#                       'can enjoy at your own pace. I went a little before '
#                       'sunset and it was beautiful!',
#               'time': 1562157408},
#              {'author_name': 'Jason Spink',
#               'author_url': 'https://www.google.com/maps/contrib/107937519060295035973/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-1v5TCYiPP2o/AAAAAAAAAAI/AAAAAAAAeO8/AmukJqs39-E/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 weeks ago',
#               'text': 'Great visit to pretty much the only thing Pisa is known '
#                       'for.  Access was well setup to the tour, and the line '
#                       'was less than 15 minutes long.  Truly enjoyed seeing '
#                       'this bit of history while in our trip\n'
#                       '\n'
#                       'More available documentation of the why and how '
#                       'surrounding the tower would be great, but if you do '
#                       'your research before you can get by',
#               'time': 1563533070},
#              {'author_name': 'Ramakrishnan Ramanathan',
#               'author_url': 'https://www.google.com/maps/contrib/109540252144258114253/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-Ruu4_6JDp5w/AAAAAAAAAAI/AAAAAAAAAE8/SI1EIkIpK-E/s128-c0x00000000-cc-rp-mo-ba6/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '4 weeks ago',
#               'text': 'Having read and heard about throughout the formative '
#                       'years; I always wanted to see this wonder. And the '
#                       'leaning tower of Pisa did not disappoint. The structure '
#                       'itself has a charm of its own. The brave endeavour to '
#                       'keep it standing despite the natural constraints is the '
#                       'other attraction. A tribute to human spirit.',
#               'time': 1562309939}],
#  'scope': 'GOOGLE',
#  'types': ['premise', 'point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=3669494377653533699',
#  'user_ratings_total': 45099,
#  'utc_offset': 120,
#  'vicinity': 'Piazza del Duomo, Pisa',
#  'website': 'http://www.opapisa.it/'}
# Fetching place details for ChIJuzIBtptoUjoRCrZi347PSQU...
# {'address_components': [{'long_name': 'Marina Beach',
#                          'short_name': 'Marina Beach',
#                          'types': ['natural_feature', 'establishment']},
#                         {'long_name': 'Chennai',
#                          'short_name': 'Chennai',
#                          'types': ['administrative_area_level_2', 'political']},
#                         {'long_name': 'Tamil Nadu',
#                          'short_name': 'TN',
#                          'types': ['administrative_area_level_1', 'political']},
#                         {'long_name': 'India',
#                          'short_name': 'IN',
#                          'types': ['country', 'political']}],
#  'adr_address': "Marina Beach, <span class='region'>Tamil Nadu</span>",
#  'formatted_address': 'Marina Beach, Tamil Nadu',
#  'geometry': {'location': {'lat': 13.0499526, 'lng': 80.2824026},
#               'viewport': {'northeast': {'lat': 13.0665385, 'lng': 80.2898802},
#                            'southwest': {'lat': 13.0209074,
#                                          'lng': 80.2778269}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',

#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/110518231765637181358/photos'>Dr "
#                                    'Sulaiman Qureshi</a>'],
#              'photo_reference': 'CmRaAAAAlx-riXJb3iWPxQUrZ-0aXKNAzohgT-7mOiHYjZ49Cev7zt6t2MBYdHhSQkXApCkgxuqh1TIS-x4zX_wrIXD92d4STGZcaHY46PgX_BuHTSZoML8CrpnPoEEaNjQRxBstEhCTv703W3Vi01bgB9P7TzmzGhTPQbu4747V3UYj3HALXylPN1KNWQ',
#              'width': 1920},
#             {'height': 2250,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/117069750857358437533/photos'>Bodhisattwa "
#                                    'Maiti</a>'],
#              'photo_reference': 'CmRaAAAAkx3WAUzyL_RM2NkzDUn7V0yaru39pc-8ur6DRviDVD86zDupx36ZOjstJjNFxp8v33EIzYngj5OolGgG6qvMH4_zjJIDcrxnkjkGSxMs-6ycYr2BHRnYLjR9sQnJ1aSHEhAeIRBUkf3oVXeN_o19Lmq_GhRy-idwOAmW4ZekSm7BBqFw4XUUCA',
#              'width': 4000},
#             {'height': 2988,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/102916534257749669493/photos'>Ismaeel "
#                                    'TradeCenter</a>'],
#              'photo_reference': 'CmRaAAAAsiuOmGSKkcsVUnpXQgbd_pVnM_kS6y14UZypL3U8uUP4yVZOR4XFkgjbFyU-4dPVw89Q2NmTXWDBfieJ9AlF19v2q6JZbEHcKk5S93flNVWnGwWM2LNORUskds-IiouAEhB5Avcx6IQyo2tri0UN6_D-GhS2gQnkGXMqkezVloxVVIeqUD3W_Q',
#              'width': 5312},
#             {'height': 4000,
#              'html_attributions': ['<a '
#                                    "href='https://maps.google.com/maps/contrib/106747379216391820458/photos'>FoodiesFest</a>"],
#              'photo_reference': 'CmRaAAAAtKo5IdQbAvmp-OnXVJ-JM4CA2w5Jj03oPi6s5UDvO2FUFpbfpnztvHdzINs4sOzQQKzu-g-0lU8xoVXEsfINbFQ2jgIJbB-eIsk-do5oKsjd-XjwsQas7M8GJTm-5I2nEhD-skXvMoauZV9H-F2mLB-sGhQLxK4bXdIhRHoJAwgVBRuIZZeBGg',
#              'width': 2000}],
#  'place_id': 'ChIJuzIBtptoUjoRCrZi347PSQU',
#  'rating': 4.3,
#  'reference': 'ChIJuzIBtptoUjoRCrZi347PSQU',
#  'reviews': [{'author_name': 'Sivasanmugam J',
#               'author_url': 'https://www.google.com/maps/contrib/100346948654377640574/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-fWUc0_1zKMQ/AAAAAAAAAAI/AAAAAAAAAAc/TEo-RPVS7Hw/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'in the last week',
#               'text': 'Nice place for evening visit  to see sun set.  Family '
#                       'beach too.  You can see so many families there. Nice '
#                       'place to play on weekends. You will definitely love the '
#                       'beach once you go there.  But you have to go as family '
#                       'or with friends so that you will enjoy alot.  People '
#                       'who needs to go alone also can go. This place will '
#                       'serve a good service for all you relaxation needs. '
#                       "There is paid parking lot. People's and some stars come "
#                       'for jogging on beach with their dogs. Some do '
#                       'gymnastics on the sand. Every one enjoy the place. Late '
#                       'night thing changes so be careful during that time '
#                       'particularly else no issue.',
#               'time': 1564725249},
#              {'author_name': 'bhavna verma',
#               'author_url': 'https://www.google.com/maps/contrib/106548594746541861750/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh4.googleusercontent.com/-EClHJF4PBSA/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rcJzGe1B4nlr-4Ar4GgWEL2SLofiQ/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#               'rating': 4,
#               'relative_time_description': 'a week ago',
#               'text': 'Try walking the coastline from the main road to the '
#                       'shore - you will understand that it certainly has the '
#                       'longest coastline. And also one can feel the '
#                       'temperature drop from the hot n sultry Chennai main '
#                       'road to the cool breeze of the Bay of Bengal.',
#               'time': 1564115877},
#              {'author_name': 'Satadru Nandigrami',
#               'author_url': 'https://www.google.com/maps/contrib/116687588939668184885/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh3.googleusercontent.com/-pEAxZEhLOYI/AAAAAAAAAAI/AAAAAAAAZP0/BErzHSQ3bHY/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg',
#               'rating': 5,
#               'relative_time_description': '2 weeks ago',
#               'text': 'Awesome place..... Soul of Chennai.... You can spend '
#                       'time with friends and family greatly.... Full of '
#                       'fun.... Lots of places to visit... Enjoy✌🏻',
#               'time': 1563380844},
#              {'author_name': 'Sathyalakshmi V',
#               'author_url': 'https://www.google.com/maps/contrib/102326062106999445136/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh3.googleusercontent.com/-jQAIum_wQTs/AAAAAAAAAAI/AAAAAAAAAcg/q4fovC-KPFg/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'a week ago',
#               'text': 'A very good place to relax with friends and family. '
#                       'Street foods are too good (lots of varieties of '
#                       'stalls). Shore premises are clean on an average basis '
#                       'only, but should ensure strict cleanliness(esp. Plastic '
#                       'waste).',
#               'time': 1563691701},
#              {'author_name': 'Jahirul Laskar',
#               'author_url': 'https://www.google.com/maps/contrib/103598741036062296149/reviews',
#               'language': 'en',
#               'profile_photo_url': 'https://lh5.googleusercontent.com/-ullp8gATI3Y/AAAAAAAAAAI/AAAAAAAAABw/o6LWPoFN6UE/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg',
#               'rating': 5,
#               'relative_time_description': 'in the last week',
#               'text': 'One of the longest beaches in the world, the Marina '
#                       'Beach  is a major tourist attraction in Chennai and '
#                       'sees thousands of visitors on a daily basis. The beach '
#                       'was developed only after the construction of the Madras '
#                       'Harbor in 1881, when the British Governor of Madras '
#                       'commissioned the construction of a promenade near the '
#                       'shoreline.',
#               'time': 1564556060}],
#  'scope': 'GOOGLE',
#  'types': ['natural_feature', 'establishment'],
#  'url': 'https://maps.google.com/?q=Marina+Beach&ftid=0x3a52689bb60132bb:0x549cf8edf62b60a',
#  'user_ratings_total': 17101,
#  'utc_offset': 330}

# %% [markdown]
# # Time Formating
#
# We shall use UTC time as reference within Experience Trail application and the format of Date Time stored is as shown below.

# %%
import pytz
import datetime

date = datetime.datetime.utcnow().replace(tzinfo=pytz.utc)
date = datetime.datetime(date.year, date.month, date.day,
                                     date.hour, date.minute, int(date.second),
                                     int(date.second * 1000000 % 1000000),
                                     tzinfo=date.tzinfo)


#'2019-08-01T10:43:30+00:00'
print(date.isoformat())
# Out:
# 2019-08-01T14:46:40+00:00
